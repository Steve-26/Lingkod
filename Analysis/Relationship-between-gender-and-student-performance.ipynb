# %% [markdown]
# # Relationship Between Gender And Student Performance in Exam

# %%
<img src="./Analysis/gender.gif"
     align= "left"
     width="500" />
# Out:
#   Input In [4]
#     <img src="./Analysis/gender.gif"
#     ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#This shows an overhead view of the Data Frame
# see first 5 rows
data= pd.read_csv('StudentsPerformance datasets.csv')
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
categorical_cols = data.select_dtypes(include='object').columns

# %%
for i in categorical_cols:
    print(data[i].unique())
# Out:
# ['female' 'male']
# ['group B' 'group C' 'group A' 'group D' 'group E']
# ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school']
# ['standard' 'free/reduced']
# ['none' 'completed']

# %% [markdown]
# ## This helps to understand each column and check out for missing values
#
# ### count null values

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
import seaborn as sns

# %%
plt.figure(figsize = (15,8))

sns.countplot(data['gender'])
# Out:
# C:\Python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# ### From the analysis above, A larger number(51.8%) of the student population are females.

# %%
count_test = data['test preparation course'].value_counts()
label = data['test preparation course'].value_counts().index
plt.figure(figsize= (18,10))
plt.pie(count_test,labels=label, autopct='%1.1f%%')
plt.legend(label)
plt.show()

# %% [markdown]
# ###   Statistics of those that attended the test preparation course. From the chart, we see that only 35.8% of the student attended/completed the test preparation course.

# %%
data['average_score']=(data['math score']+data['reading score']+data['writing score'])/3

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      average_score
# 0        72.666667
# 1        82.333333
# 2        92.666667
# 3        49.333333
# 4        76.333333
# ..             ...
# 995      94.000000
# 996      57.333333
# 997      65.000000
# 998      74.333333
# 999      83.000000
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## Student performance in subjecs based on gender

# %%
plt.figure (figsize = (18, 10))
sns.scatterplot(x=data['average_score'],y =data['math score'], hue=data['gender'])
# Out:
# <AxesSubplot:xlabel='average_score', ylabel='math score'>

# %% [markdown]
# ###                                             Male is better than female in Math test

# %%
plt.figure (figsize = (18, 10))

sns.scatterplot(x=data['average_score'],y =data['reading score'], hue=data['gender'])
# Out:
# <AxesSubplot:xlabel='average_score', ylabel='reading score'>

# %%
plt.figure (figsize = (18, 10))

sns.scatterplot(x=data['average_score'],y =data['writing score'], hue=data['gender'])
# Out:
# <AxesSubplot:xlabel='average_score', ylabel='writing score'>

# %% [markdown]
# ###   Female do better than Male in verbal test (Writing and Reading).

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      average_score
# 0        72.666667
# 1        82.333333
# 2        92.666667
# 3        49.333333
# 4        76.333333
# ..             ...
# 995      94.000000
# 996      57.333333
# 997      65.000000
# 998      74.333333
# 999      83.000000
#
# [1000 rows x 9 columns]

# %% [markdown]
# ###  Each gender has their strong and weakness in the test category. Further testing using total score and gender shows that in overall, Female perform better than Male does.
